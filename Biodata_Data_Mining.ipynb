# %%
# legislator data source: https://github.com/unitedstates/congress-legislators

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json

# %% [markdown]
# ### Read in Biographical Data from json source files

# %%
def convert_json_to_df(filename):
    with open(filename, "r") as file:
        data = json.load(file)
        
    df = pd.json_normalize(data, max_level=1)
    df['terms'] = df['terms'].apply(lambda x: x[0])
    terms_df = pd.json_normalize(df['terms'], max_level=1)
    try:
        terms_df = terms_df[['type', 'party', 'start', 'end', 'state']]
    except: # presidents don't have 'state' data
        terms_df = terms_df[['type', 'party', 'start', 'end']]
    legislator_df = pd.concat([df, terms_df], axis=1)
    try:
        legislator_df = legislator_df[['id.bioguide', 'id.wikipedia', 'name.first', 'name.middle','name.last', 
                                   'bio.gender', 'bio.birthday', 'type', 'party', 'start', 'end', 'state']]
    except: # presidents don't have 'state' data
        legislator_df = legislator_df[['id.bioguide', 'id.wikipedia', 'name.first', 'name.middle','name.last', 
                                   'bio.gender', 'bio.birthday', 'type', 'party', 'start', 'end']]
    return legislator_df

# %%
# historical_legislator_df = pd.read_json("https://theunitedstates.io/congress-legislators/legislators-historical.json")
historical_legislator_df = convert_json_to_df("legislators-historical.json")
# current_legislator_df = pd.read_json("https://theunitedstates.io/congress-legislators/legislators-current.json")
current_legislator_df = convert_json_to_df("legislators-current.json")
# presidents_df = pd.read_json("https://theunitedstates.io/congress-legislators/executive.json")
presidents_df = convert_json_to_df("presidents-and-vice-presidents.json")

# %%
print(f'historical_legislator_df: {historical_legislator_df.shape}')
print(f'current_legislator_df: {current_legislator_df.shape}')
print(f'presidents_df: {presidents_df.shape}')
# Out:
# historical_legislator_df: (12058, 12)
# current_legislator_df: (539, 12)
# presidents_df: (79, 11)

# %% [markdown]
# ### Combine All Biographical Data for the different legislators

# %%
all_legislators_df = pd.concat([historical_legislator_df, current_legislator_df, presidents_df])

# %%
all_legislators_df.isnull().sum()
# Out:
# id.bioguide       13
# id.wikipedia      77
# name.first         0
# name.middle     3987
# name.last          0
# bio.gender         0
# bio.birthday     550
# type               0
# party            218
# start              0
# end                0
# state             79
# dtype: int64

# %%
all_legislators_df.tail()
# Out:
#    id.bioguide   id.wikipedia name.first name.middle name.last bio.gender  \
# 74     B000444      Joe Biden     Joseph   Robinette     Biden          M
# 75     O000167            NaN     Barack     Hussein     Obama          M
# 76     P000587     Mike Pence       Mike         NaN     Pence          M
# 77         NaN   Donald Trump     Donald          J.     Trump          M
# 78     H001075  Kamala Harris     Kamala          D.    Harris          F
#
#    bio.birthday      type       party       start         end state
# 74   1942-11-20  viceprez    Democrat  2009-01-20  2013-01-20   NaN
# 75   1961-08-04      prez    Democrat  2009-01-20  2013-01-20   NaN
# 76   1959-06-07  viceprez  Republican  2017-01-20  2021-01-20   NaN
# 77   1946-06-14      prez  Republican  2017-01-20  2021-01-20   NaN
# 78   1964-10-20  viceprez    Democrat  2021-01-20  2025-01-20   NaN

# %% [markdown]
# ### Create new feature `full_name` on which all_legislators_df will be merged with the original PolitiFact dataset

# %%
all_legislators_df['full_name'] = all_legislators_df['name.first'] + ' ' + all_legislators_df['name.last']
all_legislators_df
# Out:
#    id.bioguide                           id.wikipedia  name.first name.middle  \
# 0      B000226  Richard Bassett (Delaware politician)     Richard         NaN
# 1      B000546         Theodorick Bland (congressman)  Theodorick         NaN
# 2      B001086                          Aedanus Burke     Aedanus         NaN
# 3      C000187                         Daniel Carroll      Daniel         NaN
# 4      C000538                          George Clymer      George         NaN
# ..         ...                                    ...         ...         ...
# 74     B000444                              Joe Biden      Joseph   Robinette
# 75     O000167                                    NaN      Barack     Hussein
# 76     P000587                             Mike Pence        Mike         NaN
# 77         NaN                           Donald Trump      Donald          J.
# 78     H001075                          Kamala Harris      Kamala          D.
#
#    name.last bio.gender bio.birthday      type                party  \
# 0    Bassett          M   1745-04-02       sen  Anti-Administration
# 1      Bland          M   1742-03-21       rep                  NaN
# 2      Burke          M   1743-06-16       rep                  NaN
# 3    Carroll          M   1730-07-22       rep                  NaN
# 4     Clymer          M   1739-03-16       rep                  NaN
# ..       ...        ...          ...       ...                  ...
# 74     Biden          M   1942-11-20  viceprez             Democrat
# 75     Obama          M   1961-08-04      prez             Democrat
# 76     Pence          M   1959-06-07  viceprez           Republican
# 77     Trump          M   1946-06-14      prez           Republican
# 78    Harris          F   1964-10-20  viceprez             Democrat
#
#          start         end state         full_name
# 0   1789-03-04  1793-03-03    DE   Richard Bassett
# 1   1789-03-04  1791-03-03    VA  Theodorick Bland
# 2   1789-03-04  1791-03-03    SC     Aedanus Burke
# 3   1789-03-04  1791-03-03    MD    Daniel Carroll
# 4   1789-03-04  1791-03-03    PA     George Clymer
# ..         ...         ...   ...               ...
# 74  2009-01-20  2013-01-20   NaN      Joseph Biden
# 75  2009-01-20  2013-01-20   NaN      Barack Obama
# 76  2017-01-20  2021-01-20   NaN        Mike Pence
# 77  2017-01-20  2021-01-20   NaN      Donald Trump
# 78  2021-01-20  2025-01-20   NaN     Kamala Harris
#
# [12676 rows x 13 columns]

# %% [markdown]
# ## Merge all_legislator_df with original PolitiFact dataset by matching on legislator name

# %%
politifact_df = pd.read_csv('politifact_data.csv')
politifact_df.shape # invalid accuracy ratings already dropped
# Out:
# (25923, 7)

# %%
politifact_df['accuracy rating'].unique()
# Out:
# array(['barely-true', 'mostly-true', 'FALSE', 'half-true', 'TRUE',
#        'pants-fire'], dtype=object)

# %%
politifact_df.head()
# Out:
#    Unnamed: 0            name       claim date       claim source  \
# 0           0  Mandela Barnes  August 17, 2022            Twitter
# 1           1    CatholicVote  August 17, 2022              an ad
# 2           2      Mark Kelly   August 5, 2022              an ad
# 3           3   Stacey Abrams   August 4, 2022              an ad
# 4           4   Beto O'Rourke    June 27, 2022  an Instagram post
#
#                                                claim     issue accuracy rating
# 0  “Ron Johnson just came out in favor of a feder...  abortion     barely-true
# 1  Three churches were targeted during arson atta...  abortion     barely-true
# 2  Blake Masters “wants to pass a national ban on...  abortion     mostly-true
# 3  "Brian Kemp wants to investigate and punish wo...  abortion           FALSE
# 4  "Under Abbott, Texas leads the nation in rape ...  abortion     mostly-true

# %% [markdown]
# #### left join politifact_df with all_legislators_df

# %%
# left join politifact_df with all_legislators_df where name matches 
all_legislators_df = all_legislators_df.drop_duplicates(subset=['full_name'])
left_joined_df = pd.merge(politifact_df, all_legislators_df, left_on='name', right_on='full_name', how='left')

# %%
left_joined_df.shape
# Out:
# (25923, 20)

# %% [markdown]
# #### inner join politifact_df with all_legislators_df

# %%
# inner join politifact_df with all_legislators_df where name matches 
all_legislators_df = all_legislators_df.drop_duplicates(subset=['full_name'])
inner_joined_df = pd.merge(politifact_df, all_legislators_df, left_on='name', right_on='full_name', how='inner')

# %%
inner_joined_df.shape
# Out:
# (7645, 20)

# %% [markdown]
# ## Check dataframes

# %% [markdown]
# ### I. Check left_joined_df

# %%
# keep running to check diff rows
left_joined_df[['name', 'bio.gender', 'bio.birthday', 'party']].sample(10)
# Out:
#                                        name bio.gender bio.birthday  \
# 21189              Americans for Prosperity        NaN          NaN
# 8020                           John Padgett        NaN          NaN
# 16665  Americans for Prosperity: New Jersey        NaN          NaN
# 18992                              Jim Webb          M   1946-02-09
# 4747                           Barack Obama          M   1961-08-04
# 19739                       Tdtalliance.com        NaN          NaN
# 19929                          Donald Trump          M   1946-06-14
# 25846                          David Quiroa        NaN          NaN
# 13261                         Jesse Ventura        NaN          NaN
# 6426                          Rick Santorum        NaN          NaN
#
#             party
# 21189         NaN
# 8020          NaN
# 16665         NaN
# 18992    Democrat
# 4747     Democrat
# 19739         NaN
# 19929  Republican
# 25846         NaN
# 13261         NaN
# 6426          NaN

# %%
left_joined_df.isnull().sum()
# Out:
# Unnamed: 0             0
# name                   0
# claim date             0
# claim source         138
# claim                  0
# issue                  0
# accuracy rating        0
# id.bioguide        19460
# id.wikipedia       18278
# name.first         18278
# name.middle        22474
# name.last          18278
# bio.gender         18278
# bio.birthday       18307
# type               18278
# party              18281
# start              18278
# end                18278
# state              19460
# full_name          18278
# dtype: int64

# %%
# 18307 null values for `bio.birthday`
bday_perc_null = (18307/left_joined_df.shape[0]) * 100
print(f'{round(bday_perc_null,2)}% of left_joined_df do not have values for `bio.birthday`.')
# Out:
# 70.62% of left_joined_df do not have values for `bio.birthday`.

# %%
# names that were not matched
left_joined_df.loc[left_joined_df['full_name'].isna()]['name'].unique().tolist()
# Out:
# ['Mandela Barnes',
#  'CatholicVote',
#  'Stacey Abrams',
#  "Beto O'Rourke",
#  'Karine Jean-Pierre',
#  'Kat Cammack',
#  'Blake Masters',
#  'National Republican Congressional Committee',
#  'Dave LaRock',
#  'Instagram posts',
#  'Planned Parenthood Votes',
#  'Kathy Hochul',
#  'Catherine Glenn Foster',
#  'Focus on the Family',
#  'Bob Good',
#  'Nikki Fried',
#  'Facebook posts',
#  'Viral image',
#  'Jonathan Turley',
#  'Joe Biden',
#  'Tweets',
#  'Tony Evers',
#  "Young America's Foundation",
#  'Candace Owens',
#  'Kelda Helen Roys',
#  'Dave McCormick',
#  'Peggy Hubbard',
#  'Pam Keith',
#  'Andrea Stewart-Cousins',
#  'National Republican Senatorial Committee',
#  'Don Beyer',
#  'Jeffrey Toobin',
#  'Jeanine Pirro',
#  'Tate Reeves',
#  'Terry McAuliffe',
#  'Greg Abbott',
#  'Occupy Democrats',
#  'Derrick Van Orden',
#  'Dean Arp',
#  'The Family Foundation',
#  'Bloggers',
#  'Republican National Committee',
#  'Nikki Haley',
#  'GayDonna Vandergriff',
#  'Association of Mature American Citizens',
#  'Kelly McGinn',
#  'Siobhan Dunnavant',
#  'Jeanne Ives',
#  'Tim Moore',
#  'Bernie Sanders',
#  'Bob Thomas',
#  'Justice Democrats',
#  'Nick Schroer',
#  'Joyce Krawiec',
#  'Donna Howard',
#  'Donna Campbell',
#  'Michael Long',
#  'Christopher Coyne',
#  'Kathy Tran',
#  'Washington State Democratic Party',
#  'Patrick Morrisey',
#  'Scott Walker',
#  'YourNewsWire.com',
#  'BlueNC',
#  'Andrew White',
#  'Jason Isaac',
#  'Say Anything Blog',
#  'NARAL Pro-Choice America',
#  'Kayla Moore',
#  'Kevin Cahill',
#  'Andrew Cuomo',
#  'Bruce Rauner',
#  'Andrew Koenig',
#  'Uspoln Website',
#  'Mary González',
#  'Social Media',
#  'Deborah Glick',
#  'Pat Robertson',
#  'Russ Feingold',
#  'DCCC',
#  'Colin Van Ostern',
#  'Colleen Deacon',
#  'Tim Kaine',
#  'Ohio Right to Life',
#  'NARAL Pro-Choice Virginia',
#  'Vicki Saporta',
#  'Maggie Hassan',
#  "Rick Scott's Starbucks heckler",
#  'James Dobson',
#  'Ken Paxton',
#  'Blake Rocap',
#  'Cecile Richards',
#  'Empower Texans',
#  "John O'Bannon",
#  'Sarah Palin',
#  "EMILY's List",
#  'Carly Fiorina',
#  'Tarina Keene',
#  'Wendy Davis',
#  'Cynthia Meyer',
#  'Jennifer Granholm',
#  'Dan Patrick',
#  'John Stemberger',
#  'Ben Carson',
#  'Dana Loesch',
#  'Victoria Cobb',
#  'Joe Pojman',
#  'Jeb Bush',
#  'Alliance Defending Freedom',
#  'Dick Black',
#  'Sandra Smith',
#  "Martin O'Malley",
#  'Ultraviolet',
#  'Karl Rove',
#  "William O'Brien",
#  'Bishop Thomas Tobin',
#  'Miscellany Blue',
#  'Texas Right to Life',
#  'Chris Taylor',
#  'Leticia Van de Putte',
#  'The Rhode Island Catholic',
#  'Democratic Senatorial Campaign Committee',
#  'Michael Eric Dyson',
#  'Newt Gingrich',
#  'Ralph Reed',
#  'American Life League',
#  'Democratic Party of Wisconsin',
#  'National Right to Life Committee',
#  'Hilary Rosen',
#  'Barth Bracy',
#  'Todd Staples',
#  'Anita Perry',
#  'Oregon 2014',
#  'Ken Cuccinelli',
#  'BookerFail',
#  'Gilberto Hinojosa',
#  'Rachel Campos-Duffy',
#  'Ohio Democratic Party',
#  'Rick Perry',
#  'Jonathan Stickland',
#  'Rachel Maddow',
#  'Sarah Ponder',
#  'Jodie Laubenberg',
#  'Ron Hood',
#  'Susan B. Anthony List',
#  'Charles Van Zant',
#  'Americans United for Life',
#  'Virginia Society for Human Life',
#  'Dan Becker',
#  'Rob Portman',
#  'Gayle Atteberry',
#  'Lenny Curry',
#  'Planned Parenthood Action Fund',
#  'Florida Democratic Party',
#  'Democratic Party of Oregon',
#  'Greater Wisconsin Committee',
#  'Tennessee Republican Party',
#  'Planned Parenthood',
#  'Shelley Adler',
#  'Government is Not God PAC',
#  'Bob McDonnell',
#  'Pam Bondi',
#  'John Wisniewski',
#  'New Hampshire Democratic Party',
#  'Samuel Wurzelbacher',
#  'Mahlon Mitchell',
#  'Wisconsin Medical Society',
#  "Jon O'Brien",
#  'Matthew Hill',
#  'Michelle Malkin',
#  'Elliott Naishtat',
#  'American Bridge 21st Century',
#  'Chris Smith',
#  'Hank Johnson',
#  'Mike DeWine',
#  'Ron Paul',
#  'Rick Santorum',
#  'Patrick Johnston',
#  'Nickie Antonio',
#  'Armond Budish',
#  'Stephanie DeSilva',
#  'Restore Our Future',
#  'Democratic National Committee',
#  'Jon Huntsman',
#  'Iowans for Some Semblance of Christian Decency',
#  'Edith Ajello',
#  'Peggy Lehner',
#  'Marjorie Dannenfelser',
#  'Steve Oelrich',
#  'Richard Corcoran',
#  'Ronald Renuart',
#  'Herman Cain',
#  'Wayne Christian',
#  'WorldNetDaily',
#  'Carol Alvarado',
#  'Liberal Blogger',
#  'Eddie Lucio, Jr.',
#  'Lorraine Fende',
#  'Heidi Group',
#  'Oregon Right to Life PAC',
#  'Pro-Life Wisconsin',
#  'Tom Barrett',
#  'Kevin Rader',
#  'Dwayne Bohac',
#  'Planned Parenthood PAC',
#  'Erick Erickson',
#  'Melanie Crozier',
#  'Ken Mercer',
#  'Republican Party of Texas',
#  'Chain email',
#  'Ed Rendell',
#  'House Republican Conference',
#  'Liberty Counsel',
#  'Glenn Beck',
#  "Bill O'Reilly",
#  'BornAliveTruth.org',
#  'MoveOn.org',
#  'Rudy Giuliani',
#  'Mike Huckabee',
#  'Log Cabin Republicans',
#  'Sam Brownback',
#  'Zach Nunn',
#  'Tom Tiffany',
#  'Patrick Testin',
#  'Richard Ojeda',
#  'The Gateway Pundit',
#  'Charlie Kirk',
#  'Jill Stein',
#  'Todd Wilcox',
#  'Jack Reed',
#  'Matt Wuerker',
#  'Bret Baier',
#  'Doonesbury',
#  'Dick Cheney',
#  'David Alameel',
#  'Robert Gibbs',
#  'John Scocos',
#  'Cokie Roberts',
#  'BillHislam.com',
#  'Michelle Obama',
#  'Ted Ankrum',
#  'Michael J. Gardiner',
#  'Elizabeth Dennigan',
#  'Paul Krugman',
#  'Alexi Giannoulias',
#  'Ed Schultz',
#  'Colin Powell',
#  'Joe Lieberman',
#  'Pray in Jesus Name Project',
#  'Gary Black',
#  'Kathy Barnette',
#  'Team PAC',
#  'NaturalNews.com',
#  'Pat McCrory',
#  'Shelley Moore Capito',
#  'Jill Karofsky',
#  'Lorraine Lewandrowski',
#  'Survival International',
#  'Theresa Greenfield',
#  'Paul Farrow',
#  'John Nygren',
#  'Gavin Newsom',
#  'Sonny Perdue',
#  'Trey Blocker',
#  'Southwest Farm Press',
#  'Sean Spicer',
#  'Gordon Hintz',
#  'World Food Program',
#  'Danielle Nierenberg',
#  'Jeannette Vaught',
#  'Luis Gutierrez',
#  'U.S. Dairy Export Council',
#  'Heather Moore',
#  'Centers for Disease Control',
#  'Sid Miller',
#  'Donna Nesselbush',
#  'Georgia Farm Bureau',
#  'Mother Jones',
#  'Michelle Nunn',
#  'Oregon Department of Agriculture',
#  'Kentucky Opportunity Coalition',
#  'Donna Brazile',
#  'Amardeep Kaleka',
#  'Rick North',
#  'American Crossroads',
#  'Tom Rooney',
#  'James Durkan',
#  'Frank Niceley',
#  'Susan Combs',
#  'Corn Commentary',
#  'Renewable Fuels Association',
#  'Wisconsin Corn Growers Association',
#  'Glenn Hegar',
#  'Jamie Radtke',
#  'New Georgia Encyclopedia',
#  'Tom Coburn',
#  'Jim Zehringer',
#  'Pat Quinn',
#  'Stephen Hayes',
#  'Dale Peterson',
#  'Hank Gilbert',
#  'Kinky Friedman',
#  '"Watch The Water"',
#  'South West News Service',
#  'YouTube videos',
#  'Jimmy Anderson',
#  'Jim Justice',
#  'Alexander Strenger',
#  'Ann Hudspeth',
#  'Will Herring',
#  'Betsy DeVos',
#  'Rob Wittman',
#  'Stacy White',
#  'Minka Kelly',
#  "Shawn O'Connor",
#  'Unbreakable Kimmy Schmidt',
#  'Chris Larson',
#  'Jack Hanna',
#  'Limberbutt McCubbins',
#  'SeaWorld',
#  'Florida Students for Concealed Carry',
#  'Matt Bevin',
#  'Hugh Fitzsimons',
#  'Richard August',
#  'People for the Ethical Treatment of Animals',
#  'Al Gore',
#  'Jim Sensenbrenner',
#  'Alberta Darling',
#  'American Bird Conservancy',
#  'Joe Negron',
#  'Marion Hammer',
#  'Kirk Watson',
#  'Central Falls Police Department',
#  'Peter Palumbo',
#  'Pew Environment Group',
#  'National Rifle Association',
#  'American Civil Liberties Union of Florida',
#  'Maria Sachs',
#  'Bear Education and Resource Group',
#  'Gail Collins',
#  'Elaine Boyer',
#  'Wisconsin Humane Society',
#  'Kathleen Passidomo',
#  'E.J. Finocchio',
#  'truthcommand.com',
#  'Jim Carrey',
#  'The Associated Press',
#  'José Oliva',
#  'Jack Lew',
#  'Center for Individual Freedom',
#  'John Oliver',
#  'Steven Costantino',
#  'Allan Fung',
#  'Dawson Hodgson',
#  'David Dewhurst',
#  'Charlene Lima',
#  'Jim Taricani',
#  "People's Majority",
#  'Robert Jacquard',
#  'Theresa Price',
#  'George Nee',
#  'Vincent "Buddy" Cianci',
#  'Daniel McKee',
#  'Matthew Dowd',
#  'Citizens for the Republic',
#  'Sharron Angle',
#  'Ed Whitacre',
#  'Cathie Adams',
#  'Chris Dodd',
#  'Michael Steele',
#  'Chris Carr',
#  'Snapple',
#  'John DePetro',
#  'Tim Lee',
#  'Steven Frias',
#  'James Skeffington',
#  'Revitalize Cobb',
#  'John Loud',
#  'Jeffrey Loria',
#  'Dennis Algiere',
#  'Evan Longoria',
#  'Sam Adams',
#  'Yvette McGee Brown',
#  'Stuart Sternberg',
#  'George Will',
#  'Americans United for Change',
#  'Francesca Hong',
#  'Wisconsin Initiative',
#  'Jon Erpenbach',
#  'Paul Junge',
#  'Congressional Leadership Fund',
#  'Chele Farley',
#  'Dan Kohl',
#  'New Leadership PAC',
#  'Jay Chaudhuri',
#  'Our Democracy 2020',
#  'Dana Wachs',
#  'NowThis',
#  'Ryan Frazier',
#  'Jack Falanagan',
#  'Jennifer Horn',
#  'Mackubin Thomas Owens',
#  'Lon Burnam',
#  'Senate Majority PAC',
#  'Kenneth Block',
#  'Jim Rubens',
#  'New Hampshire Republican Party',
#  'Kesha Rogers',
#  'Rush Limbaugh',
#  'Ian Prior',
#  'Janet Napolitano',
#  'Steve LaTourette',
#  'Tom Niehaus',
#  'Brendan Doherty',
#  'Mark Strama',
#  'Jeff Fitzgerald',
#  'Club for Growth',
#  'Paul Sadler',
#  'Oregon Republican Party',
#  'Charlotte Bergmann',
#  'Rob Cornilles',
#  'David Axelrod',
#  'Brett Hulsey',
#  'Adam Hasner',
#  'Jay Carney',
#  'Herb Kohl',
#  'Tom DeLay',
#  'Raging Elephants',
#  'Allan Ritter',
#  'Dean Wright',
#  'Mark Hinkle',
#  'Steve Munisteri',
#  'Democratic Governors Association',
#  'Mark S. Zaccaria',
#  'Bryan Underwood',
#  'Libertarian Party of Texas',
#  'Danny Tarkanian',
#  'Bill Clinton',
#  "Foundation for Florida's Future",
#  'Dave Aronberg',
#  'JB Pritzker',
#  'Letitia James',
#  'Bennett Sandlin',
#  'Jose Carrillo',
#  'Ronna McDaniel',
#  'Charlie Geren',
#  'Maram Museitif',
#  'Jack Berry',
#  'Sylvester Turner',
#  'Charlotte Nash',
#  'Julián Castro',
#  'Jason Carter',
#  'Will Wynn',
#  'U.S. Census Bureau',
#  'Elisabeth Hasselbeck',
#  'Charlotte Lehan',
#  'Joe Brown',
#  'Glee',
#  'Tom Kean Jr.',
#  'Garnet Coleman',
#  'Terry Gorman',
#  'Steven Brown',
#  'John Faulk',
#  'Lone Star Project',
#  'Ronnie Earle',
#  'Bill Bennett',
#  'Sarah Godlewski',
#  'Chris Murphy',
#  'Marjorie Taylor Greene',
#  'Jack Posobiec',
#  'Sonia Sotomayor',
#  'Steve Kirsch',
#  'Robert Reich',
#  'Rebecca Kleefisch',
#  'Larry Elder',
#  'Jill Underly',
#  'Brandon Tatum',
#  'LaKeshia Myers',
#  'Melissa Agard',
#  'Chris Kapenga',
#  'Paula Jean Swearengin',
#  'American Principles Project',
#  'Nicole Galloway',
#  'Van Wanggaard',
#  'Kim Reynolds',
#  'Tucker Carlson',
#  'Michael Bloomberg',
#  'David Crowley',
#  'Woody Thrasher',
#  'Tracy McCreery',
#  'Dale Kooyenga',
#  'Shelia Stubbs',
#  'Jeremiah Samples',
#  'Lena Taylor',
#  'Children at Risk',
#  'Mary Elizabeth Coleman',
#  'House Majority PAC',
#  'A Stronger Wisconsin',
#  'Fox News Channel',
#  'Republican Party of Wisconsin',
#  'Matt Flynn',
#  'Leah Vukmir',
#  'Lupe Valdez',
#  'Scott Milder',
#  'tmzbreaking',
#  'Tom Luce',
#  "Committee of Austin's Children PAC",
#  'Joyce Mauk',
#  'Samantha Bee',
#  'Margaret Hoover',
#  'Kathleen Vinehout',
#  'Restore American Freedom and Liberty',
#  'Duane Hall',
#  'Lumos',
#  'Caleb Rowden',
#  'Conservative Daily Post',
#  'Chelsea Clinton',
#  'Ertharin Cousin',
#  'Baker Harrell',
#  'Tina Rosenberg',
#  'Reince Priebus',
#  'Americans For Prosperity, North Carolina chapter',
#  'Austin Independent School District',
#  'Don Willett',
#  'John Pagliarini',
#  'Rebecca Bradley',
#  'Katie McGinty',
#  'Anthony Rendon',
#  'Jill Vogel',
#  'Common Sense Kids Action',
#  'Greenville Gazette',
#  'Edward Flynn',
#  'Randy Forbes',
#  'Mike Tate',
#  'Rebecca Quigley',
#  'Dino Baccari',
#  'Rose Mary Grant',
#  'Susan Stimpson',
#  'Ken Plum',
#  'Susan Pitman',
#  'Erika Sanzi',
#  'Karina Wood',
#  'Nationwide',
#  'Rhode Island Center for Freedom and Prosperity',
#  'Claire Suggs',
#  'James Crowley',
#  'Everytown for Gun Safety',
#  'Anne Nolan',
#  'William Benson Huber',
#  'Mary Burke',
#  'Cormick Lynch',
#  'Jake Tapper',
#  'Joe Leibham',
#  'Raul Labrador',
#  'Nan Rich',
#  'Jimmy Carter',
#  'Betsy Miller-Jones',
#  'Allen Peake',
#  'Tom Harkin',
#  'Physicians Committee for Responsible Medicine',
#  'Sondy Pope',
#  'Jennifer Parrish',
#  'Oregon Center for Public Policy',
#  'Dream Defenders',
#  'Don Lemon',
#  'Teresa Tanzi',
#  'Joseph McNamara',
#  'Jason Conger',
#  'Oregon PTA',
#  'Carolyn Tomei',
#  'Robert Deuell',
#  'Family Forward Oregon',
#  'Joee Lindbeck',
#  'Fix Austin Schools',
#  'Oregon Health Authority',
#  'Mike Villarreal',
#  'Susan Yoshihara',
#  'Deborah Gist',
#  'Larry Valencia',
#  'Joseph Levy',
#  'Diane McKeel',
#  'College presidents',
#  'Dan Saltzman',
#  'Texas Values',
#  "Tomorrow's Vision of Florida",
#  'Gerard Robinson',
#  'Rudy Moise',
#  'Rashad Taylor',
#  'Laurie Monnes Anderson',
#  'David A. Clarke Jr.',
#  'Richard Tomlins',
#  'Doreen Costa',
#  'Raymond Lesniak',
#  'Gary Sasse',
#  'Rob Eissler',
#  'Amy Hanauer',
#  'Stephen Wise',
#  'Roberto DaSilva',
#  'Whoopi Goldberg',
#  'Get EQUAL Texas',
#  'Oregon Healthy Kids',
#  "Children's Healthcare of Atlanta",
#  'Americans for Common Sense Solutions',
#  'Yes on 8',
#  'Vote NO on 8',
#  'Lone Star First',
#  'Alex Sink',
#  'J.B. Van Hollen',
#  'Debbie Riddle',
#  'Bill White',
#  'Carol Morgan',
#  'Rodney Ellis',
#  'Kay Bailey Hutchison',
#  'Mike Gibbons',
#  'Mehmet Oz',
#  'Stand Up To China',
#  'Don Huffines',
#  'John James',
#  'Andrew Yang',
#  'Anthony Scaramucci',
#  'Don Blankenship',
#  'One Wisconsin Now',
#  'Rex Tillerson',
#  'Colorado Citizens for Accountable Government',
#  'Celia Israel',
#  'Thomas Perez',
#  'Joe Donald',
#  'Kevin Russell',
#  'Matthew Cooke',
#  'Xi Jinping',
#  'Clint Eastwood',
#  'Let Freedom Ring',
#  'Americans For Tax Reform',
#  'Anthony Gemma',
#  'Edd Houck',
#  'Jim Lamon',
#  'Steve Kerr',
#  'Mike Franken',
#  'Mauro Garza',
#  'Jonathon Moseley',
#  'Chuck Todd',
#  'Iowa Republican Party',
#  'Hillsborough County Republican Executive Committee',
#  'Community Oncology Alliance',
#  'Heritage Action',
#  'Black Lives Matter',
#  'Turning Point USA',
#  'Tom Nelson',
#  'Act for America',
#  'Eric Trump',
#  'Michigan Democratic Party',
#  'Jeff Bezos',
#  'AFL-CIO',
#  'Brandon Morse',
#  'Jim Himes',
#  'Greg Steube',
#  'Mike Shields',
#  'Roland Martin',
#  'Politics WatchDog',
#  'Chuck Woolery',
#  'E. Gordon Gee',
#  'Andrea Mitchell',
#  'Richard Cordray',
#  'M.J. Hegar',
#  'Jim Renacci',
#  'Roland Gutierrez',
#  'Corey Stewart',
#  'Jessica Morse',
#  'Fareed Zakaria',
#  'Tom Palzewicz',
#  'Randy Bryce',
#  'Republican Party of Florida',
#  'Jonathan Saenz',
#  'International News Trends',
#  'Political Thinkers',
#  "Uncle Sam's Misguided Children",
#  'Mary Taylor',
#  'Kellyanne Conway',
#  'Phil Ting',
#  'CSC Mediagroup.USA',
#  'USA Trainnews',
#  'The Patriot Report',
#  'Democrats Rising',
#  'USA In Front',
#  'Senate Leadership Fund',
#  'US Daily News 24',
#  'Greg Gutfeld',
#  'Principled PAC',
#  'Save My Care',
#  'Arnold Schwarzenegger',
#  'Fight for the Future',
#  'American Future Fund',
#  'Anna Throne-Holst',
#  'End Citizens United',
#  'Majority Forward',
#  'Dave Brat',
#  'Zephyr Teachout',
#  'Gary Johnson',
#  'Tim Canova',
#  "Colorado's Voice",
#  'Roy Zimmerman',
#  'Right to Rise',
#  'Jon Keyser',
#  'Stephanie Schriock',
#  'American Action Network',
#  'Reader',
#  "Institute for Women's Policy Research",
#  'Brook Hines',
#  'Ann McLane Kuster',
#  'Phil Kerpen',
#  'Sergey Lavrov',
#  'Chris Wallace',
#  'Color of Change',
#  'Laura Ingraham',
#  'Maria Cardona',
#  'Ending Spending Action Fund',
#  'Alison Lundergan Grimes',
#  'Freedom Partners',
#  'Concerned Veterans for America',
#  'Bill Maher',
#  'Put Alaska First PAC',
#  'Ronan Farrow',
#  'Madison Action Fund',
#  'Defending Main Street',
#  'Jonathan Boucher',
#  'Clay Aiken',
#  'Ari Melber',
#  'Democratic Congressional Campaign Committee',
#  'Mike Scott',
#  'Carla Axtman',
#  'Edward Lindsey',
#  'Chris Latvala',
#  'Steve Lonegan',
#  'Campaign for Liberty - Georgia',
#  'Christine Whitman',
#  'Bobby Scott',
#  'Josh Mandel',
#  'Jesse Ventura',
#  'Tommy Thompson',
#  'Michael Riley',
#  'Chris Redfern',
#  'Protect Your Vote Ohio',
#  'Lou Ann Zelenik',
#  'Scott Keyes',
#  'Daniel Rodriguez',
#  'Stephen Simpson',
#  'Tennessee Democratic Party',
#  'Beth Harwell',
#  'Chris Christie',
#  'Weston Wamp',
#  'Campaign for Primary Accountability',
#  'Becky Moeller',
#  'Karen Harrington',
#  'Einer Elhauge',
#  'Pitbull',
#  'One Nation',
#  'One America News',
#  'Jane Timken',
#  'Rob Astorino',
#  'David Willis',
#  'Mary Felzkowski',
#  'Wisconsin Senate Republicans',
#  'Blaine Wilhour',
#  'TikTok posts',
#  'Patrick Gaspard',
#  'Infowars',
#  'Nicole Sirotek',
#  'NewsWars',
#  'Christine Drazan',
#  'Aaron Rodgers',
#  'Reiner Fuellmich',
#  'America First Political Committee',
#  'Jen Psaki',
#  'Save America PAC',
#  'Peter McCollough',
#  'Robert F. Kennedy, Jr.',
#  'Alex Berenson',
#  'Alex Jones',
#  'Conservative Beaver',
#  'Ron Klain',
#  'Hal Turner Radio Show',
#  'The Charlie Kirk Show',
#  'Carrie Madej',
#  'Kimberly Klacik',
#  'Will Cain',
#  '10 GOP Louisiana Lawmakers',
#  'Anthony Fauci',
#  'Kathryn Moffett Bradford',
#  'Terri Bryant',
#  'Joe Rogan',
#  'Roy Cooper',
#  'Democratic Underground',
#  'Erin Marie Olszewski',
#  'Dan Stock',
#  'Steve Deace',
#  'Josh Stein',
#  'Tomi Lahren',
#  'Liz Wheeler',
#  'Kedron Bardwell',
#  'Sherri Tenpenny',
#  'Jeffrey Zients',
#  'Missouri House Democratic Caucus',
#  'Zach Wahls',
#  'Diamond and Silk',
#  'Janet Bewley',
#  'Pete Snyder',
#  'James Edming',
#  'Aubrey Huff',
#  'Ron Kim',
#  'Karen Brinson Bell',
#  'Stand for America',
#  'Simone Gold',
#  'J. Bart Classen',
#  'Buck Sexton',
#  'Billboard',
#  "Dan O'Donnell",
#  'Illinois Republican Party',
#  'Mark Born',
#  'Lee Merritt',
#  'Stefan Mychajliw',
#  'Jim Steineke',
#  'Ryan Fournier',
#  'Mandy Cohen',
#  'Colin Schmitt',
#  'Garlin Gilchrist',
#  'Pat Toomey',
#  'Kirk Cox',
#  'Jon Rosenthal',
#  'North Carolina Republican Party',
#  'Christi Craddick',
#  'Duey Stroebel',
#  'Robin Vos',
#  'Donald Trump Jr.',
#  'Tom Brady',
#  'Sri Preston Kulkarni',
#  'Mike Parson',
#  'DeAnna Lorraine',
#  'MacIver Institute',
#  'William Barr',
#  'Mun Choi',
#  'Dan Forest',
#  'Kayleigh McEnany',
#  'Michael Caputo',
#  'Paul Sperry',
#  'Brett Giroir',
#  'Wisconsin state Senate Democrats',
#  'Michael Schraa',
#  'Stella Immanuel',
#  'West Virginia Democratic Party',
#  'Sean Hannity',
#  'Public Citizen',
#  'Melissa Melendez',
#  'Chris Hayes',
#  'Greg Murphy',
#  'Priorities USA Action',
#  'Monica Wallace',
#  'Desiree Rogers',
#  'George Borrello',
#  'J. Christian Adams',
#  'Darren Jackson',
#  'Joe Kernen',
#  'Janel Brandtjen',
#  'Iowa Democratic Party',
#  'Kimberly Lightford',
#  'Nick Freitas',
#  'Mike Turzai',
#  'Coalition for the Homeless',
#  'Louis Riggs',
#  'Jeff Shipley',
#  'Cal Cunningham',
#  'Jerome R. Corsi',
#  'Ralph Northam',
#  'Gary Kelly',
#  'Warren Daniel',
#  'Lincoln Project',
#  'Nate McMurray',
#  'Cindy O’Laughlin',
#  'Jamie Nadler',
#  'Steve Bannon',
#  'Franklin Graham',
#  'Lovely Warren',
#  'Levar Stoney',
#  'Wisconsin Republican Legislative leaders',
#  'Phil McGraw',
#  'Gretchen Whitmer',
#  'Jeff Jackson',
#  'Lori Lightfoot',
#  'John Bel Edwards',
#  'Jesse Watters',
#  'Jerome Adams',
#  'Chain message',
#  'Kelly Alexander',
#  'Sherill Sellman',
#  'Michael Dougherty',
#  'Ainsley Earhardt',
#  'Joy Behar',
#  'Dr. Drew Pinsky',
#  'Lou Dobbs',
#  'YourContent',
#  'Chad Wolf',
#  'Erica Smith',
#  'Janet Yellen',
#  'Christina Blackcloud',
#  'Jeff Williams',
#  'Tim Burns',
#  'Andy Gronik',
#  'Jennifer Shilling',
#  'Aaron DeGroot',
#  'Food & Water Watch',
#  'John Skvarla',
#  'Robin Wright',
#  'Steve Adler',
#  'Gina Raimondo',
#  'Ed Gillespie',
#  'The Commonwealth Institute',
#  'Anonymous cyber-squatter',
#  'Trebor Banstetter',
#  'Republican State Leadership Committee',
#  'Angel Taveras',
#  'Bob Beckel',
#  'Eric Bolling',
#  'Burger King',
#  'Eugene Sepulveda',
#  'NextGen Climate Action Committee',
#  'Erin Lynch',
#  'Charles Koch',
#  'AFL-CIO of New Jersey',
#  'Vincent Fort',
#  'American International Group',
#  'Majority PAC',
#  'Barry Hinckley',
#  'Joseph Kyrillos',
#  "Workers' Voice",
#  'We Are Milwaukee',
#  'We Are Wisconsin',
#  'Americans for Prosperity',
#  'Stephen Laffey',
#  'New Jersey Senate Democrats',
#  'AFSCME',
#  'Occupy Providence',
#  'Robert Kraig',
#  'SEIU',
#  'Jon Husted',
#  'Jeff Tittel',
#  'Sergio Marchionne',
#  'Jim Moran',
#  'Progressive Change Campaign Committee',
#  'Bumper Sticker',
#  'National Taxpayers Union',
#  'Keith Stokes',
#  'David Gregory',
#  'Stephen Archambault',
#  'Jeff Greene',
#  'Arianna Huffington',
#  'Chris Matthews',
#  'Katrina vanden Heuvel',
#  'Lawrence Summers',
#  'Jay Rockefeller',
#  'Health Care for America Now',
#  "Investor's Business Daily",
#  'American Leadership Action',
#  'Ben Kral',
#  'Cavalier Johnson',
#  'Eric Toney',
#  'Dennis Prager',
#  'Keith Pekau',
#  'Crystal Peoples-Stokes',
#  'Kevin Nicholson',
#  'Tom Suozzi',
#  'Richard Irvin',
#  'Vladimir Putin',
#  "Dinesh D'Souza",
#  'Doug Wilder',
#  'NYS Department of Corrections and Community Supervision',
#  'Byron Brown',
#  'Katie Pavlich',
#  'Greg Kelly',
#  'Shannon Grove',
#  'Uniting Missouri PAC',
#  'George P. Bush',
#  'Sunny Hostin',
#  'Joe Morrissey',
#  'Joe Sanfelippo',
#  'Paul Maner',
#  'Philip Van Cleave',
#  'Jeff Jensen',
#  'New York City Police Benevolent Association',
#  'Rob Hutton',
#  'Paul Gigot',
#  'Jean Evans',
#  'Curt Schilling',
#  'Ivanka Trump',
#  'Sheila Bynum-Coleman',
#  'Chelsea Handler',
#  'Bill Stanley',
#  'Pete Buttigieg',
#  'Jared Kushner',
#  'Paul Bettencourt',
#  'Garry McCarthy',
#  'Florida Strong',
#  ...]

# %% [markdown]
# ### II. Check inner_joined_df

# %%
# keep running to check diff rows
inner_joined_df[['name', 'bio.gender', 'bio.birthday', 'party']].sample(10)
# Out:
#                   name bio.gender bio.birthday       party
# 5952  Scott Fitzgerald          M   1963-11-16  Republican
# 4325        Rick Scott          M   1952-12-01  Republican
# 5685   Patrick Kennedy          M   1967-07-14    Democrat
# 4330        Rick Scott          M   1952-12-01  Republican
# 7415        Tom Marino          M   1952-08-15  Republican
# 766        John Cornyn          M   1952-02-02  Republican
# 2032     Kamala Harris          F   1964-10-20    Democrat
# 769        John Cornyn          M   1952-02-02  Republican
# 7543      Ruben Kihuen          M   1980-04-25    Democrat
# 2187       Marco Rubio          M   1971-05-28  Republican

# %%
inner_joined_df.isnull().sum()
# Out:
# Unnamed: 0            0
# name                  0
# claim date            0
# claim source         39
# claim                 0
# issue                 0
# accuracy rating       0
# id.bioguide        1182
# id.wikipedia          0
# name.first            0
# name.middle        4196
# name.last             0
# bio.gender            0
# bio.birthday         29
# type                  0
# party                 3
# start                 0
# end                   0
# state              1182
# full_name             0
# dtype: int64

# %%
bday_perc_null = (18307/inner_joined_df.shape[0]) * 100
print(f'{round(bday_perc_null,2)}% of inner_joined_df do not have values for `bio.birthday`.')
# Out:
# 239.46% of inner_joined_df do not have values for `bio.birthday`.

# %% [markdown]
# ### Save both  left_joined_df and inner_joined_df to CSV file

# %%
# save left_joined_df with 25k rows
left_joined_df.to_csv("politifact_data_with_bio_raw.csv")

# save inner_joined_df with 7k rows
inner_joined_df.to_csv("politifact_data_with_bio.csv")
