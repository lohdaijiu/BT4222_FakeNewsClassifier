# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("politifact_with_bio_data_raw.csv")
df
# Out:
#        Unnamed: 0            name       claim_date  \
# 0               0  Mandela Barnes  August 17, 2022
# 1               1    CatholicVote  August 17, 2022
# 2               2      Mark Kelly   August 5, 2022
# 3               3   Stacey Abrams   August 4, 2022
# 4               4   Beto O'Rourke    June 27, 2022
# ...           ...             ...              ...
# 25918       25918    Barack Obama     May 27, 2009
# 25919       25919   Arlen Specter   March 24, 2009
# 25920       25920  Michelle Obama  August 25, 2008
# 25921       25921  Michelle Obama  August 25, 2008
# 25922       25922    Barack Obama   April 18, 2008
#
#                                             claim_source  \
# 0                                                Twitter
# 1                                                  an ad
# 2                                                  an ad
# 3                                                  an ad
# 4                                      an Instagram post
# ...                                                  ...
# 25918                                           a speech
# 25919                       a speech on the Senate floor
# 25920  her address at the Democratic National Convention
# 25921                                             Denver
# 25922                                    a television ad
#
#                                                    claim     issue  \
# 0      “Ron Johnson just came out in favor of a feder...  abortion
# 1      Three churches were targeted during arson atta...  abortion
# 2      Blake Masters “wants to pass a national ban on...  abortion
# 3      "Brian Kemp wants to investigate and punish wo...  abortion
# 4      "Under Abbott, Texas leads the nation in rape ...  abortion
# ...                                                  ...       ...
# 25918  In the 100 days since its passage, the economi...   workers
# 25919  The Employee Free Choice Act mandates the "eli...   workers
# 25920  As a state senator in Illinois, Obama made sur...   workers
# 25921  While in the Illinois Senate, Barack Obama pas...   workers
# 25922  Hillary Clinton is "willing to have workers' w...   workers
#
#       accuracy_rating id.bioguide   id.wikipedia name.first name.middle  \
# 0         barely-true         NaN            NaN        NaN         NaN
# 1         barely-true         NaN            NaN        NaN         NaN
# 2         mostly-true     K000377     Mark Kelly       Mark         NaN
# 3               FALSE         NaN            NaN        NaN         NaN
# 4         mostly-true         NaN            NaN        NaN         NaN
# ...               ...         ...            ...        ...         ...
# 25918     barely-true     O000167   Barack Obama     Barack         NaN
# 25919     mostly-true     S000709  Arlen Specter      Arlen         NaN
# 25920     mostly-true         NaN            NaN        NaN         NaN
# 25921     mostly-true         NaN            NaN        NaN         NaN
# 25922       half-true     O000167   Barack Obama     Barack         NaN
#
#       name.last bio.gender bio.birthday type       party      start  \
# 0           NaN        NaN          NaN  NaN         NaN        NaN
# 1           NaN        NaN          NaN  NaN         NaN        NaN
# 2         Kelly          M    21/2/1964  sen    Democrat  2/12/2020
# 3           NaN        NaN          NaN  NaN         NaN        NaN
# 4           NaN        NaN          NaN  NaN         NaN        NaN
# ...         ...        ...          ...  ...         ...        ...
# 25918     Obama          M     4/8/1961  sen    Democrat   4/1/2005
# 25919   Specter          M    12/2/1930  sen  Republican   5/1/1981
# 25920       NaN        NaN          NaN  NaN         NaN        NaN
# 25921       NaN        NaN          NaN  NaN         NaN        NaN
# 25922     Obama          M     4/8/1961  sen    Democrat   4/1/2005
#
#               end state      full_name
# 0             NaN   NaN            NaN
# 1             NaN   NaN            NaN
# 2        3/1/2023    AZ     Mark Kelly
# 3             NaN   NaN            NaN
# 4             NaN   NaN            NaN
# ...           ...   ...            ...
# 25918  16/11/2008    IL   Barack Obama
# 25919    3/1/1987    PA  Arlen Specter
# 25920         NaN   NaN            NaN
# 25921         NaN   NaN            NaN
# 25922  16/11/2008    IL   Barack Obama
#
# [25923 rows x 20 columns]

# %%
drop_values = ['full-flop', 'half-flip', 'no-flip']
df = df[~df['accuracy_rating'].isin(drop_values)]
df
# Out:
#        Unnamed: 0            name       claim_date  \
# 0               0  Mandela Barnes  August 17, 2022
# 1               1    CatholicVote  August 17, 2022
# 2               2      Mark Kelly   August 5, 2022
# 3               3   Stacey Abrams   August 4, 2022
# 4               4   Beto O'Rourke    June 27, 2022
# ...           ...             ...              ...
# 25918       25918    Barack Obama     May 27, 2009
# 25919       25919   Arlen Specter   March 24, 2009
# 25920       25920  Michelle Obama  August 25, 2008
# 25921       25921  Michelle Obama  August 25, 2008
# 25922       25922    Barack Obama   April 18, 2008
#
#                                             claim_source  \
# 0                                                Twitter
# 1                                                  an ad
# 2                                                  an ad
# 3                                                  an ad
# 4                                      an Instagram post
# ...                                                  ...
# 25918                                           a speech
# 25919                       a speech on the Senate floor
# 25920  her address at the Democratic National Convention
# 25921                                             Denver
# 25922                                    a television ad
#
#                                                    claim     issue  \
# 0      “Ron Johnson just came out in favor of a feder...  abortion
# 1      Three churches were targeted during arson atta...  abortion
# 2      Blake Masters “wants to pass a national ban on...  abortion
# 3      "Brian Kemp wants to investigate and punish wo...  abortion
# 4      "Under Abbott, Texas leads the nation in rape ...  abortion
# ...                                                  ...       ...
# 25918  In the 100 days since its passage, the economi...   workers
# 25919  The Employee Free Choice Act mandates the "eli...   workers
# 25920  As a state senator in Illinois, Obama made sur...   workers
# 25921  While in the Illinois Senate, Barack Obama pas...   workers
# 25922  Hillary Clinton is "willing to have workers' w...   workers
#
#       accuracy_rating id.bioguide   id.wikipedia name.first name.middle  \
# 0         barely-true         NaN            NaN        NaN         NaN
# 1         barely-true         NaN            NaN        NaN         NaN
# 2         mostly-true     K000377     Mark Kelly       Mark         NaN
# 3               FALSE         NaN            NaN        NaN         NaN
# 4         mostly-true         NaN            NaN        NaN         NaN
# ...               ...         ...            ...        ...         ...
# 25918     barely-true     O000167   Barack Obama     Barack         NaN
# 25919     mostly-true     S000709  Arlen Specter      Arlen         NaN
# 25920     mostly-true         NaN            NaN        NaN         NaN
# 25921     mostly-true         NaN            NaN        NaN         NaN
# 25922       half-true     O000167   Barack Obama     Barack         NaN
#
#       name.last bio.gender bio.birthday type       party      start  \
# 0           NaN        NaN          NaN  NaN         NaN        NaN
# 1           NaN        NaN          NaN  NaN         NaN        NaN
# 2         Kelly          M    21/2/1964  sen    Democrat  2/12/2020
# 3           NaN        NaN          NaN  NaN         NaN        NaN
# 4           NaN        NaN          NaN  NaN         NaN        NaN
# ...         ...        ...          ...  ...         ...        ...
# 25918     Obama          M     4/8/1961  sen    Democrat   4/1/2005
# 25919   Specter          M    12/2/1930  sen  Republican   5/1/1981
# 25920       NaN        NaN          NaN  NaN         NaN        NaN
# 25921       NaN        NaN          NaN  NaN         NaN        NaN
# 25922     Obama          M     4/8/1961  sen    Democrat   4/1/2005
#
#               end state      full_name
# 0             NaN   NaN            NaN
# 1             NaN   NaN            NaN
# 2        3/1/2023    AZ     Mark Kelly
# 3             NaN   NaN            NaN
# 4             NaN   NaN            NaN
# ...           ...   ...            ...
# 25918  16/11/2008    IL   Barack Obama
# 25919    3/1/1987    PA  Arlen Specter
# 25920         NaN   NaN            NaN
# 25921         NaN   NaN            NaN
# 25922  16/11/2008    IL   Barack Obama
#
# [25923 rows x 20 columns]

# %%
df = df[df['party'].notna()]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# name                  0
# claim_date            0
# claim_source         39
# claim                 0
# issue                 0
# accuracy_rating       0
# id.bioguide        1182
# id.wikipedia          0
# name.first            0
# name.middle        4193
# name.last             0
# bio.gender            0
# bio.birthday         29
# type                  0
# party                 0
# start                 0
# end                   0
# state              1182
# full_name             0
# dtype: int64

# %%
df.shape
# Out:
# (7642, 20)

# %%
df.to_csv("test.csv")
